# %%
#load libraries 
import time,os
from matplotlib.offsetbox import AnchoredText
import sys,pandas as pd, matplotlib , matplotlib.pyplot as plt, matplotlib.lines , numpy as np, math, pylab
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
#import cudf
#import ROOT
#from ROOT import TFile

#import root_pandas
import importlib
#from toggle_cell import hide_cell 
# %matplotlib inline

#presets for plot style
golden = (np.sqrt(2)+1)/2
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (10, 10/golden),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
pylab.rcParams.update(params)

viridis = cm.get_cmap('viridis', 12)
inferno = cm.get_cmap('inferno', 12)
autumn = cm.get_cmap('autumn', 12)

#physical_devices = tf.config.list_physical_devices('GPU')
#tf.config.experimental.set_memory_growth(physical_devices[0], True)
#tf.config.experimental.set_memory_growth(physical_devices[1], True)
rc = plt.rc
rc('text', usetex=False)
import matplotlib as mpl
rc('font', family='serif')
rc('text', usetex=False)
rc('font', size=15)
rc('xtick', labelsize=15)
rc('ytick', labelsize=15)
rc('legend', fontsize=15)


import ROOT
import collections
pdg = ROOT.TDatabasePDG()

plt.rcParams['figure.facecolor']='white'
plt.rcParams['savefig.facecolor']='white'
plt.rcParams['savefig.bbox']='tight'
# Out:
# Warning in <TDatabasePDG::TDatabasePDG>: object already instantiated

# %%
#D0 decay modes:
fracs=[]
labels=[]

#add lines like these for several of the decay modes.  
labels.append("$K^+\pi^-$")
fracs.append(3.947)

labels.append("$K^+K^-$")
fracs.append(.408)  #maybe we could enhance our statistics slightly by also including this decay mode.

labels.append("$\pi^+\pi^-$\n\n")
fracs.append(.1454)  #maybe?  maybe we could enhance our statistics slightly by also including this decay mode.


fracs.append(100-sum(fracs))
labels.append("other")

autopct = lambda x: ('%.1f%%'%x if x>.3 else '%.1f%%  \n' %x)
plt.pie(fracs, labels=labels, autopct=autopct)
plt.title("$\\bar D_0$ decay modes")
plt.show()

# %%
#lambda_c -> n + X modes

# %%
#Lambda c + decay modes:
fracs=[]
labels=[]
#non-mu,n,p final states
labels.append("$\\Lambda^0 e^+\\nu_e$")
fracs.append(3.6)  #maybe we could enhance our statistics slightly by also including this decay mode.

#lambda_0 intermediate states #INCLUSIVE BRANCHING 38.2 %
#mu final states
labels.append("$\\Lambda^0 \\mu^+\\nu_\\mu$")
fracs.append(3.5)

#p or n from lambda_0 final states (no channels with direct n or p and lambda_0 intermediate)
labels.append("$\\Lambda^0 \\pi^+$")
fracs.append(1.3)

labels.append("$\\Lambda^0 \\pi^+ \\pi^0$")
fracs.append(1.1) #includes intermediate rho^+ state

labels.append("$\\Lambda^0 \\rho^+$")
fracs.append(6.0)

labels.append("$\\Lambda^0 K^0 K^+$")
fracs.append(0.57) 

#labels.append("$\\Lambda^0 \\pi^- 2\\pi^+$ ***") #requires 1 -> 4 generator
#fracs.append(3.64)

labels.append("$\\Lambda^0 \\pi^+ \\rho^0$")
fracs.append(1.5)
#direct decay n final states
labels.append("$n \\pi^+ K^0_S$")
fracs.append(1.8)

#p or n from Sigma_charged final states

#p or n from Sigma0 final states

#direct decay p final states


fracs.append(100-sum(fracs))
labels.append("other")

#autopct = lambda x: ('%.1f%%'%x if x>5 else '')
plt.pie(fracs, labels=labels, autopct='%.1f%%')#autopct=autopct)
plt.title("$\Lambda^0_c$ decay modes")
plt.show()
